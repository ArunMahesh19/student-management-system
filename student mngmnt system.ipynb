# %%
import pymysql
from tkinter import messagebox


from tkinter import*
from tkinter import ttk
r=Tk()
r.geometry("1350x700+0+0")
r.title("Student Managment system")
titellabel=Label(r,text="STUDENT MANAGMENT SYSTEM",font=("Arial",30,"bold"),border=12,relief=GROOVE,bg="lightgray")
titellabel.pack(side=TOP,fill=X)


###### FUNCTION ###################
def createconn():
    return pymysql.connect(host="localhost",database="data",user="root",password="7807128874",port=3306)
def insertdata():
    Rollno=rollno_entry.get()
    Name=name_entry.get()
    Class=class_entry.get()
    Section=section_entry.get()
    Contact=contact_entry.get()
    Fathersname=fath_entry.get()
    Address=adress_entry.get()
    Gender=gender_entry.get()
    Dob=dateofbirth_entry.get()
    conn=createconn()
    cursor=conn.cursor()
    args=(Rollno,Name,Class,Section,Contact,Fathersname,Address,Gender,Dob)
    query="insert into student(Rollno,Name,Class,Section,Contact,Fathersname,Address,Gender,Dob)values(%s,%s,%s,%s,%s,%s,%s,%s,%s)"
    cursor.execute(query,args)
    conn.commit()
    conn.close()
    print("date inserted") 
    if Rollno=="":
        messagebox.showerror("error","please enter your Roll No")
    elif Name=="":
        messagebox.showerror("error","please enter your Name")
    elif Class=="":
        messagebox.showerror("error","please enter your Class")
    elif Section=="":
        messagebox.showerror("error","please enter your Section")
    elif Contact=="":
        messagebox.showerror("error","please enter your Contact no")
    elif Fathersname=="":
        messagebox.showerror("error","please enter your Father's Name")
    elif Address=="":
        messagebox.showerror("error","please enter your Address")
    elif Dob=="":
        messagebox.showerror("error","please enter your Date of birth")
    else:
        messagebox.showinfo("Success","registartion succesfully")
        fetch_data()


    
    
def fetch_data():
    conn=createconn()
    cursor=conn.cursor()
    cursor.execute("select * from student")
    output=cursor.fetchall()
    if len(output)!=0:
        student_tabel.delete(*student_tabel.get_children())
        for i in output:
            student_tabel.insert('' ,END, values=i)
        conn.commit()
        conn.close()
        
def Delete():
    conn=createconn()
    cursor=conn.cursor()
    cursor.execute("delete from student where name='Hunny'")
    conn.commit()
    
def update():
    Rollno=rollno_entry.get()
    Name=name_entry.get()
    Class=class_entry.get()
    Section=section_entry.get()
    Contact=contact_entry.get()
    Fathersname=fath_entry.get()
    Address=adress_entry.get()
    Gender=gender_entry.get()
    Dob=dateofbirth_entry.get()
    conn=createconn()
    cursor=conn.cursor()
    update_query=("UPDATE  'student' SET 'Name'=%s WHERE 'Rollno'=%s")
    vals=(Name,Rollno)
    cursor.execute(update_query,vals)
    conn.commit()
  
    


    
    
    
def clear():
    rollno_entry.delete(0,END)
    name_entry.delete(0,END)
    class_entry.delete(0,END)
    section_entry.delete(0,END)
    contact_entry.delete(0,END)
    fath_entry.delete(0,END)
    adress_entry.delete(0,END)
    gender_entry.delete(0,END)
    dateofbirth_entry.delete(0,END)
    
    
  
        
############## LABEL FRAME MAIN & DATA FRAME #######################


detail_frame=LabelFrame(r,text="Enter Details",font=("Arial",20),bd=12,relief=GROOVE,bg="lightgray")
detail_frame.place(x=20,y=100,height=560,width=420)
data_frame=LabelFrame(r,bd=12,relief=GROOVE,bg="lightgray")
data_frame.place(x=475,y=90,height=575,width=810)



############ LABELS & ENTRY #################

rollno_label=Label(detail_frame,text="Roll No",font=("Arial",15),bg="lightgray")
rollno_label.grid(row=0,column=0,padx=2,pady=2)
rollno_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
rollno_entry.grid(row=0,column=1,padx=2,pady=2)

name_label=Label(detail_frame,text="Name",font=("Arial",15),bg="lightgray")
name_label.grid(row=1,column=0,padx=2,pady=2)
name_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
name_entry.grid(row=1,column=1,padx=2,pady=2)

class_label=Label(detail_frame,text="Class",font=("Arial",15),bg="lightgray")
class_label.grid(row=2,column=0,padx=2,pady=2)
class_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
class_entry.grid(row=2,column=1,padx=2,pady=2)

section_label=Label(detail_frame,text="Section",font=("Arial",15),bg="lightgray")
section_label.grid(row=3,column=0,padx=2,pady=2)
section_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
section_entry.grid(row=3,column=1,padx=2,pady=2)

contact_label=Label(detail_frame,text="Contact",font=("Arial",15),bg="lightgray")
contact_label.grid(row=4,column=0,padx=2,pady=2)
contact_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
contact_entry.grid(row=4,column=1,padx=2,pady=2)

fath_label=Label(detail_frame,text="Father's Name",font=("Arial",15),bg="lightgray")
fath_label.grid(row=5,column=0,padx=2,pady=2)
fath_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
fath_entry.grid(row=5,column=1,padx=2,pady=2)

adress_label=Label(detail_frame,text="Address",font=("Arial",15),bg="lightgray")
adress_label.grid(row=6,column=0,padx=2,pady=2)
adress_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
adress_entry.grid(row=6,column=1,padx=2,pady=2)


gender_label=Label(detail_frame,text="Gender",font=("Arial",15),bg="lightgray")
gender_label.grid(row=7,column=0,padx=2,pady=2)
gender_entry=ttk.Combobox(detail_frame,font=("Arial",15),state="readonly")
gender_entry["values"]=("Male","Female","Other")
gender_entry.grid(row=7,column=1,padx=2,pady=2)

dateofbirth_label=Label(detail_frame,text="D.O.B",font=("Arial",15),bg="lightgray")
dateofbirth_label.grid(row=8,column=0,padx=2,pady=2)
dateofbirth_entry=Entry(detail_frame,bd=7,bg="lightgray",font=("Arial",15))
dateofbirth_entry.grid(row=8,column=1,padx=2,pady=2)


###################### BUTTON  ##########################

button_frame=Frame(detail_frame,bd=10,bg="lightgray",relief=GROOVE)
button_frame.place(x=18,y=390,width=354,height=120)

add_btn=Button(button_frame,text="Add",bg="lightgray",bd=7,font=("Arial",13),width=15,command=insertdata)
add_btn.grid(row=0,column=0,padx=2,pady=2)

update_btn=Button(button_frame,text="Update",bg="lightgray",bd=7,font=("Arial",13),width=15,command=update)
update_btn.grid(row=0,column=1,padx=2,pady=2)

dlt_btn=Button(button_frame,text="Delete",bg="lightgray",bd=7,font=("Arial",13),width=15,command=Delete)
dlt_btn.grid(row=2,column=0,padx=2,pady=2)

dlt_btn=Button(button_frame,text="Clear",bg="lightgray",bd=7,font=("Arial",13),width=15,command=clear)
dlt_btn.grid(row=2,column=1,padx=2,pady=2)





################### SEARCH ##########################

search_frame=Frame(data_frame,bd=10,bg="lightgray",relief=GROOVE)
search_frame.pack(side=TOP,fill=X)


search_label=Label(search_frame,text="Search",font=("Arial",14),bg="lightgray")
search_label.grid(row=0,column=0,padx=2,pady=2)

searchcombo=ttk.Combobox(search_frame,font=("Arial",14),state="readonly")
searchcombo["values"]=("Name","Roll NO","Conatct No","Fathers Name","Class","Section","D.O.B")
searchcombo.grid(row=0,column=1,padx=12,pady=2)

search_btn=Button(search_frame,text="Search",bg="lightgray",bd=9,font=("Arial",13),width=14)
search_btn.grid(row=0,column=2,padx=12,pady=2)

showall_btn=Button(search_frame,text="Show All",bg="lightgray",bd=9,font=("Arial",13),width=14)
showall_btn.grid(row=0,column=3,padx=12,pady=2)



#############  DATABASE FRAME  ###########################3

main_frame=Frame(data_frame,bd=11,bg="lightgray",relief=GROOVE)
main_frame.pack(expand=True,fill=BOTH)

y_scroll=Scrollbar(main_frame,orient=VERTICAL)
x_scroll=Scrollbar(main_frame,orient=HORIZONTAL)

student_tabel=ttk.Treeview(main_frame,columns=("Roll No","Name","Class","Section","Contact","Fathers Name","Address","Gender","D.O.B"))
y_scroll.config(command=student_tabel.yview)
x_scroll.config(command=student_tabel.xview)
y_scroll.pack(side=RIGHT,fill=Y)
x_scroll.pack(side=BOTTOM,fill=X)
student_tabel.heading("Roll No",text="Roll No.")
student_tabel.heading("Name",text="Name")
student_tabel.heading("Class",text="Class")
student_tabel.heading("Section",text="Section")
student_tabel.heading("Contact",text="Contact")
student_tabel.heading("Fathers Name",text="Fathers Name")
student_tabel.heading("Address",text="Address")
student_tabel.heading("Gender",text="Gender")
student_tabel.heading("D.O.B",text="D.O.B")

student_tabel["show"]="headings"


student_tabel.column("Roll No",width=100)
student_tabel.column("Name",width=100)
student_tabel.column("Class",width=100)
student_tabel.column("Section",width=100)
student_tabel.column("Contact",width=100)
student_tabel.column("Fathers Name",width=100)
student_tabel.column("Address",width=100)
student_tabel.column("Gender",width=100)
student_tabel.column("D.O.B",width=100)
student_tabel.pack(fill=BOTH,expand=True)



fetch_data()

mainloop()
